# %%
import pandas as pd

houseData = pd.read_csv("housingData.csv")
priceData =
# Out:
#                         suburb    type   rent         value  oldRent  \
# 0    ACT Remainder - Belconnen  houses  680.0  5.554528e+05      NaN
# 1    ACT Remainder - Gungahlin  houses  680.0  7.397478e+05    695.0
# 2                      Ainslie  houses  700.0  1.204675e+06    695.0
# 3                 Amaroo (ACT)  houses  585.0  8.191847e+05    572.5
# 4                       Aranda  houses  635.0  1.208682e+06    650.0
# ..                         ...     ...    ...           ...      ...
# 153                     Turner   units  520.0  5.302558e+05    500.0
# 154                  Wanniassa   units  465.0  4.045805e+05    400.0
# 155                     Watson   units  450.0  4.095398e+05    420.0
# 156                     Wright   units  480.0  4.247181e+05    450.0
# 157                 Yarralumla   units  550.0  1.033055e+06    630.0
#
#         oldValue  changeRent  changeValue
# 0            NaN         NaN          NaN
# 1    388683.1232   -0.021583     0.903216
# ...
